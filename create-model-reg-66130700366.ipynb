# %%
cd /content/drive/MyDrive/!698-1-2025/Lec12-Regression
# Out:
# /content/drive/MyDrive/!698-1-2025/Lec12-Regression

# %%
ls
# Out:
# advertising.csv                     deploy-model-66130700366.ipynb
# Ass-Regression+Analysis.pdf         exp-regression-66130700366.ipynb
# create-model-reg-66130700366.ipynb  model-reg-66130700366.pkl

# %% [markdown]
# Step 1: read the data from a CSV file named ”advertising.csv”.

# %%
import pandas as pd
df = pd.read_csv('advertising.csv')

# %% [markdown]
# Step 2: Split the data into features (X) and target (y)

# %%
X = df[['youtube', 'tiktok', 'instagram']]
y = df['sales']

# %% [markdown]
# Step 3: Build and train the Linear Regression model using the entire dataset

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X, y)
# Out:
# LinearRegression()

# %% [markdown]
# Step 4: Save model as "model-reg-xxx.pkl"

# %%
import joblib
joblib.dump(model, 'model-reg-66130700366.pkl')
# Out:
# ['model-reg-66130700366.pkl']

# %%
print("Model trained and saved as model-reg-66130700366.pkl successfully!")
# Out:
# Model trained and saved as model-reg-66130700366.pkl successfully!

# %% [markdown]
# สร้างไฟล์ app.py

# %%
# %%writefile app.py
import joblib
import pandas as pd
import streamlit as st

st.set_page_config(page_title="Sales Prediction", page_icon="📈", layout="centered")
st.title("📈 Sales Prediction (Linear Regression)")

# โหลดโมเดล
@st.cache_resource
def load_model():
    model = joblib.load("model-reg-xxx.pkl")
    feature_order = ["youtube", "tiktok", "instagram"]
    return model, feature_order

try:
    model, feature_order = load_model()
    st.success("Model loaded successfully.")
except Exception as e:
    st.error(f"Cannot load model-reg-xxx.pkl: {e}")
    st.stop()

st.markdown("กรอกงบโฆษณาแต่ละช่องทางแล้วคลิก **Predict**")

col1, col2, col3 = st.columns(3)
with col1:
    youtube = st.number_input("youtube", min_value=0.0, value=50.0, step=1.0)
with col2:
    tiktok = st.number_input("tiktok", min_value=0.0, value=50.0, step=1.0)
with col3:
    instagram = st.number_input("instagram", min_value=0.0, value=50.0, step=1.0)

if st.button("Predict"):
    X = pd.DataFrame([[youtube, tiktok, instagram]], columns=feature_order)
    y_hat = model.predict(X)[0]
    st.success(f"Estimated sales: **{y_hat:.2f}**")
# Out:
# Writing app.py

# %%
# %%writefile requirements.txt
# streamlit
# pandas
# scikit-learn
# joblib
# Out:
# Writing requirements.txt

# %%
# !ls -l
# Out:
# total 182
# -rw------- 1 root root   4069 Oct 19 06:12 advertising.csv
# -rw------- 1 root root   1190 Oct 19 08:29 app.py
# -rw------- 1 root root 133222 Oct 19 06:12 Ass-Regression+Analysis.pdf
# -rw------- 1 root root  22150 Oct 19 08:28 create-model-reg-66130700366.ipynb
# -rw------- 1 root root   3639 Oct 19 07:38 deploy-model-66130700366.ipynb
# -rw------- 1 root root  18165 Oct 19 06:39 exp-regression-66130700366.ipynb
# -rw------- 1 root root    865 Oct 19 08:28 model-reg-66130700366.pkl
# -rw------- 1 root root     37 Oct 19 08:29 requirements.txt
